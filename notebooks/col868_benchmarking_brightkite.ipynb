# %%
# !pip install torch-cluster 
# !pip install torch-scatter==latest+cu101 torch-sparse==latest+cu101 torch-spline-conv==latest+cu101 -f https://s3.eu-central-1.amazonaws.com/pytorch-geometric.com/whl/torch-1.4.0.html
# !pip install torch-geometric
# !pip install tensorboardX
# Out:
# ...
#   Created wheel for torch-cluster: filename=torch_cluster-1.4.5-cp36-cp36m-linux_x86_64.whl size=20364325 sha256=e69d43651b4a02a0b9f67b80db4d80e1bb789c6fa00f2fa4dea11a2ca002c037
#   Stored in directory: /root/.cache/pip/wheels/0a/26/7e/a6d6a80eae5ca39b92bc77773f36cf433d5085de18014382b1
# Successfully built torch-cluster
# ...
# Looking in links: https://s3.eu-central-1.amazonaws.com/pytorch-geometric.com/whl/torch-1.4.0.html
# ...
#      |████████████████████████████████| 10.6MB 356kB/s
# ...
#      |████████████████████████████████| 11.5MB 40.2MB/s
# ...
#      |████████████████████████████████| 5.1MB 57.1MB/s
# ...
#      |████████████████████████████████| 143kB 2.8MB/s
# ...
#      |████████████████████████████████| 348kB 42.7MB/s
# ...
#      |████████████████████████████████| 51kB 6.5MB/s
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-1.4.2-cp36-none-any.whl size=224447 sha256=aad3420e18917c0315c6c307ee22f5949c893b4216373c6a562a2c9adbe440f6
# ...

# %%
# !python main.py --model GCN --dataset brightkite
# Out:
# Namespace(aggr='mean', anchor_num=64, approximate=-1, batch_size=8, cache=False, comment='0', cuda='0', dataset='brightkite', dropout=True, epoch_log=10, epoch_num=2001, feature_dim=32, feature_pre=True, gpu=True, hidden_dim=32, layer_num=2, lr=0.01, model='GCN', normalize_adj=False, output_dim=32, permute=True, remove_link_ratio=0.2, repeat_num=2, rm_feature=False, task='link')
# Using GPU 0
# Original nodes: 58228
# Original edges: 214078
# Sampled nodes: 10000
# Sampled edges: 79402
# returned datalist
# 0 Data(edge_index=[2, 158804], x=[10000, 1])
# finished link masking
# finished appending
# dists removed
# tcmalloc: large alloc 1200005120 bytes == 0x684f6000 @  0x7fa3d68952a4 0x592727 0x4dddf7 0x4e3200 0x4e284a 0x4e14d8 0x4e2c5b 0x4e34a4 0x4e3ac6 0x454557 0x50a9da 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40 0x7fa3d6491b97 0x5b2fda
# Cache saved!
# brightkite load time 785.6359431743622
# ...
